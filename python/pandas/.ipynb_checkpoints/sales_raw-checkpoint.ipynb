# %%
import pandas as pd

df = pd.read_csv("../files/csv/sales_raw.csv")
df['price'] = df['price'].apply(pd.to_numeric, errors='coerce')
cols = ['event_time', 'sale_date']
df[cols] = df[cols].apply(pd.to_datetime, errors='coerce')
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   order_id    2000 non-null   int64
#  1   item        2000 non-null   str
#  2   price       1503 non-null   float64
#  3   notes       2000 non-null   str
#  4   status      2000 non-null   str
#  5   event_time  2000 non-null   datetime64[us]
#  6   sale_date   2000 non-null   datetime64[us]
# dtypes: datetime64[us](2), float64(1), int64(1), str(3)
# memory usage: 109.5 KB
