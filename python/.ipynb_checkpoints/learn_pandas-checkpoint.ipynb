# %%
import pandas as pd

series = pd.Series([num * 10 for num in range(1, 11)])
series
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 3
#       1 import pandas as pd
#       2
# ----> 3 series = pd.Series([num * 10 for num in range(1, 11)], index="a")
#       4 series
#
# File ~/Desktop/Dhanasekaran Workspace/learning_workspace/python/.venv/lib/python3.14/site-packages/pandas/core/series.py:423, in Series.__init__(self, data, index, dtype, name, copy)
#     420 name = ibase.maybe_extract_name(name, data, type(self))
#     422 if index is not None:
# --> 423     index = ensure_index(index)
#     425 if dtype is not None:
#     426     dtype = self._validate_dtype(dtype)
#
# File ~/Desktop/Dhanasekaran Workspace/learning_workspace/python/.venv/lib/python3.14/site-packages/pandas/core/indexes/base.py:7975, in ensure_index(index_like, copy)
#    7973         return Index(index_like, copy=copy, tupleize_cols=False)
#    7974 else:
# ...
